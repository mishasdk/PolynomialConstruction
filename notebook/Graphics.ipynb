# %%
import sys
import os
import sympy as sp
from numpy import linspace

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"/src/python")

import com.bulumutka.polyconstr.FindExpression as ex
import matplotlib.pyplot as mpl


path = '../data/'

def drawPlot(expected, actual):
    T = sp.symbols('T')
    a = sp.lambdify(T, expected, modules=['numpy'])
    b = sp.lambdify(T, actual, modules=['numpy'])
    x = linspace(0, 1000, 100)
    mpl.plot(x, b(x), 'b', label='actual')
    mpl.plot(x, a(x), 'r', label='expected')
    mpl.xlabel('T')
    mpl.ylabel('R(T)')
    mpl.legend(loc='upper left')
    mpl.show()

# %% [markdown]
# $K_3$ graph

# %%
# Expected
T = sp.symbols('T')
expected_formulas = ex.find_k_graph(3, [1, 1, 1])
expected_formulas
# Out:
# 3*T**2/4 + 1.5*T

# %%
# Actual
v = ex.read_vector(path + 'K3_graph_vector.txt')
actual_formulas = ex.find_polynomial(v)
actual_formulas
# Out:
# 0.75*T**2 + 8.0*T + 10.75

# %%
mpl.title('Actual and expected polynoms for K_3')
drawPlot(expected_formulas, actual_formulas)

# %% [markdown]
# $K_4$ graph

# %%
# Expected
expected_formulas = ex.find_k_graph(4, [1 for i in range(6)])
expected_formulas
# Out:
# T**5/80 + 1.875*T**2

# %%
# Actual
v = ex.read_vector(path + 'K4_graph_vector.txt')
actual_formulas = ex.find_polynomial(v)
actual_formulas
# Out:
# 0.0125*T**5 + 0.78125*T**4 + 14.3125*T**3 + 100.46875*T**2 + 268.90625*T + 242.078125

# %%
mpl.title('Actual and expected polynoms for K_4')
drawPlot(expected_formulas, actual_formulas)

# %% [markdown]
# $K_5 graph$

# %%
# Expected
expected_formulas = ex.find_k_graph(5, [1 for i in range(10)])
expected_formulas
# Out:
# T**9/290304 + 0.9375*T**3

# %%
# Actual
v = ex.read_vector(path + 'K5_graph_vector.txt')
actual_formulas = ex.find_polynomial(v)
actual_formulas
# Out:
# 3.44466490299824e-6*T**9 + 0.000697544642857142*T**8 + 0.048549107142857*T**7 + 1.65364583333332*T**6 + 31.3148437499988*T**5 + 347.172851562498*T**4 + 2279.95117187501*T**3 + 8674.78766741072*T**2 + 17820.5630301338*T + 15481.6351329984

# %%
mpl.title('Actual and expected polynoms for K_5')
drawPlot(expected_formulas, actual_formulas)

# %% [markdown]
# $C_4 graph$

# %%
expected_formulas = ex.find_cycle_graph(4, [1 for i in range(4)])
expected_formulas
# Out:
# T**3/6 + 3*T**2/4

# %%
v = ex.read_vector(path + 'cycle_4_vector.txt')
actual_formulas = ex.find_polynomial(v)
actual_formulas
# Out:
# 0.166666666666667*T**3 + 3.75*T**2 + 16.75*T + 17.0

# %%
drawPlot(expected_formulas, actual_formulas)

# %% [markdown]
# $C_6 graph$

# %%
v = ex.read_vector(path + 'cycle_6_vector.txt')
expected_formulas = ex.find_cycle_graph(6, [1 for i in range(6)])
expected_formulas
# Out:
# T**5/320 + 5*T**4/128

# %%
actual_formulas = ex.find_polynomial(v)
actual_formulas
# Out:
# 0.003125*T**5 + 0.1953125*T**4 + 2.94270833333333*T**3 + 14.90625*T**2 + 40.6015625*T + 42.2291666666667

# %%
drawPlot(expected_formulas, actual_formulas)

# %% [markdown]
# $C_{10} graph$

# %%
v = ex.read_vector(path + 'cycle_10_vector.txt')
expected_formulas = ex.find_cycle_graph(10, [1 for i in range(10)])
expected_formulas
# Out:
# T**9/9289728 + T**8/229376

# %%
actual_formulas = ex.find_polynomial(v)
actual_formulas
# Out:
# 1.07645778218695e-7*T**9 + 2.17982700892857e-5*T**8 + 0.00114978608630952*T**7 + 0.0203125*T**6 + 0.28165283203125*T**5 + 2.79922146267361*T**4 + 18.8986789279514*T**3 + 81.3521251860119*T**2 + 198.839584592789*T + 206.91897999597

# %%
drawPlot(expected_formulas, actual_formulas)

# %% [markdown]
# $C_{16} graph$

# %%
v = ex.read_vector(path + 'cycle_16_vector.txt')
expected_formulas = ex.find_cycle_graph(16, [1 for i in range(16)])
expected_formulas
# Out:
# T**15/1339058552832000 + T**14/11902742691840

# %%
actual_formulas = ex.find_polynomial(v)
actual_formulas
# Out:
# 7.46793333185529e-16*T**15 + 4.2007124991686e-13*T**14 + 6.28286566125651e-11*T**13 + 2.82965174822746e-9*T**12 + 1.19714133979406e-7*T**11 + 4.14594771370055e-6*T**10 + 0.000113094079594927*T**9 + 0.00241270853969125*T**8 + 0.0401662712717093*T**7 + 0.519012026723731*T**6 + 5.14455066683992*T**5 + 38.3033019233499*T**4 + 206.791822621527*T**3 + 762.198299141668*T**2 + 1710.6713613521*T + 1759.34509919258

# %%
drawPlot(expected_formulas, actual_formulas)
